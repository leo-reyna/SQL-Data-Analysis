# %%
import psycopg2 as pg2

# %%
# !pip install psycopg2-binary
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
conn = pg2.connect(
   database = "dvdrental", user="postgres", password="LaKretadeFidel_10", host="localhost", port="5432"
   )

# %%
cur = conn.cursor()

# %%
cur.execute("SELECT * FROM payment;")
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 cur.execute("SELECT * FROM payment;")
#
# InterfaceError: cursor already closed

# %%
cur.fetchone()
# Out:
# (17503,
#  341,
#  2,
#  1520,
#  Decimal('7.99'),
#  datetime.datetime(2007, 2, 15, 22, 25, 46, 996577))

# %%
cur.fetchmany(5)
# Out:
# [(17504,
#   341,
#   1,
#   1778,
#   Decimal('1.99'),
#   datetime.datetime(2007, 2, 16, 17, 23, 14, 996577)),
#  (17505,
#   341,
#   1,
#   1849,
#   Decimal('7.99'),
#   datetime.datetime(2007, 2, 16, 22, 41, 45, 996577)),
#  (17506,
#   341,
#   2,
#   2829,
#   Decimal('2.99'),
#   datetime.datetime(2007, 2, 19, 19, 39, 56, 996577)),
#  (17507,
#   341,
#   2,
#   3130,
#   Decimal('7.99'),
#   datetime.datetime(2007, 2, 20, 17, 31, 48, 996577)),
#  (17508,
#   341,
#   1,
#   3382,
#   Decimal('5.99'),
#   datetime.datetime(2007, 2, 21, 12, 33, 49, 996577))]

# %%
conn.close()
